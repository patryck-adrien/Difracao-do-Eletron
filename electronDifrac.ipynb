# %% [markdown]
# Imports libraries

# %%
import chardet
import numpy as np
import scipy as sp
from scipy import stats
import scipy.constants as constants
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_excel('difeletron.ods', engine='odf')

dataFrame

# print(dataFrame['Voltagem (kV)'])
# Out:
#     Voltagem (V)  Raio interno (cm)  Raio externo (cm)  Comprimento de onda  \
# 0           2000                4.7                7.1         2.742138e-11
# 1           2500                3.7                6.2         2.452643e-11
# 2           3000                3.2                5.1         2.238946e-11
# 3           3500                2.9                4.8         2.072861e-11
# 4           4000                2.6                4.4         1.938984e-11
# 5           4500                2.3                4.2         1.828092e-11
# 6           5000                2.3                3.8         1.734280e-11
# 7           5500                2.3                3.7         1.653571e-11
# 8           6000                2.2                3.4         1.583174e-11
# 9           6500                2.0                3.3         1.521064e-11
# 10          7000                1.8                3.1         1.465734e-11
# 11          7500                1.8                2.7         1.416034e-11
#
#     Comprimento de onda (Picometro)  Unnamed: 5 Unnamed: 6    Unnamed: 7  \
# 0                         27.421378         NaN        NaN           NaN
# 1                         24.526426         NaN        NaN           NaN
# 2                         22.389462         NaN        NaN           NaN
# 3                         20.728614         NaN        NaN           NaN
# 4                         19.389843         NaN        NaN           NaN
# 5                         18.280919         NaN        NaN           NaN
# 6                         17.342802         NaN        NaN           NaN
# 7                         16.535713         NaN        NaN           NaN
# 8                         15.831740         NaN          h  6.625000e-34
# 9                         15.210644         NaN          e  1.602000e-19
# 10                        14.657343         NaN          m  9.109000e-31
# 11                        14.160339         NaN          R  6.500000e+01
#
#     Unnamed: 8    Unnamed: 9
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN
# 5          NaN           NaN
# 6          NaN           NaN
# 7          NaN           NaN
# 8          NaN           NaN
# 9          NaN  3.333333e+24
# 10         NaN           NaN
# 11         NaN           NaN

# %%
# d1 = [3.1, 2.8, 2.5, 2.3, 2.1, 2.0, 1.9, 1.7, 1.7, 1.5, 1.5, 1.7, 1.6, 1.5, 1.5, 1.4]
# d2 = [5.5, 4.9, 4.3, 4.1, 3.9, 3.8, 3.6, 3.4, 3.1, 2.9, 2.9, 3.0, 2.9, 2.8, 2.7, 2.7]

# d1 = [3.1, 3.4, 2.8, 2.9, 2.5, 2.9, 2.3, 2.6, 2.1, 2.4, 2.0, 2.2, 1.9, 2.1, 1.7, 2.0, 1.7, 2.0, 1.5, 1.8, 1.5, 1.9, 1.7, 1.7, 1.6, 1.7, 1.5, 1.7, 1.5, 1.5, 1.4]
# d2 = [5.5, 5.7, 4.9, 4.9, 4.3, 5.2, 4.1, 4.7, 3.9, 4.2, 3.8, 3.9, 3.6, 3.8, 3.4, 3.6, 3.1, 3.5, 2.9, 3.3, 2.9, 3.2, 3.0, 3.0, 2.9, 2.9, 2.8, 2.9, 2.7, 2.7, 2.7]

# D1 = [4.8, 3.8, 4.0, 3.5, 3.7, 3.4, 3.3, 3.0, 2.9, 2.7, 2.8, 2.6, 2.5, 2.4, 2.4, 2.4, 2.2, 2.3, 2.0, 2.2, 2.1, 2.1, 2.0, 2.0, 1.9, 2.0, 1.9, 1.9, 1.8, 1.7, 1.7]
# D2 = [7.4, 7.4, 6.5, 5.9, 6.1, 5.9, 5.2, 5.1, 4.9, 4.7, 4.5, 4.5, 4.3, 4.0, 4.2, 3.9, 3.8, 3.8, 3.8, 3.7, 3.4, 3.5, 3.5, 3.4, 3.2, 3.2, 3.1, 3.1, 3.1, 2.9, 3.0]

D1 = dataFrame['Raio interno (cm)']
D2 = dataFrame['Raio externo (cm)']

r1 = []
r2 = []
for i in range(len(D1)):
  r1.append(D1[i]*10/2.0)
  r2.append(D2[i]*10/2.0)

dif1 = r1
dif2 = r2

# r1 = []
# r2 = []
# for i in range(len(d1)):
#   r1.append(d1[i]*10/2.0)
#   r2.append(d2[i]*10/2.0)

# dif1 = []
# dif2 = []
# for i in range(len(R1)):
#   dif1.append(np.abs(R1[i] - r1[i]))
#   dif2.append(np.abs(R2[i] - r2[i]))

# print(R1)
# print(R2)

# print(r1)
# print(r2)

e1 = []
e2 = []

for i in range(len(r1)):
  e1.append(1.0/r1[i])
  e2.append(1.0/r2[i])

print(e1)
print(e2)
# Out:
# [0.0425531914893617, 0.05405405405405406, 0.0625, 0.06896551724137931, 0.07692307692307693, 0.08695652173913043, 0.08695652173913043, 0.08695652173913043, 0.09090909090909091, 0.1, 0.1111111111111111, 0.1111111111111111]
# [0.028169014084507043, 0.03225806451612903, 0.0392156862745098, 0.041666666666666664, 0.045454545454545456, 0.047619047619047616, 0.05263157894736842, 0.05405405405405406, 0.058823529411764705, 0.06060606060606061, 0.06451612903225806, 0.07407407407407407]

# %%
e = dataFrame['Voltagem (V)']
me = 9.109*10e-31
qe = 1.602*10e-19
h = 6.625*10e-35

# convertendo para volt: (deixar em SI)
# for i in range(len(e)):
#   e[i] = e[i]*1000
# print("energia convertida:")
# print(e)

lamb = dataFrame['Comprimento de onda (Picometro)']
# for i in range(len(e)):
#   lamb.append((h/np.sqrt(2.0*me*qe*e[i])))
# print(lamb)

# # convertendo para picometro:
# for i in range(len(lamb)):
#   lamb[i] = lamb[i]*10e12
print(lamb)
# Out:
# 0     27.421378
# 1     24.526426
# 2     22.389462
# 3     20.728614
# 4     19.389843
# 5     18.280919
# 6     17.342802
# 7     16.535713
# 8     15.831740
# 9     15.210644
# 10    14.657343
# 11    14.160339
# Name: Comprimento de onda (Picometro), dtype: float64

# %%
D = 127.0

theta1 = []
for i in range(len(r1)):
  theta1.append((1.0/4.0)*np.arcsin(2*r1[i]/D))
print(theta1)

theta2 = []
for i in range(len(r2)):
  theta2.append((1.0/4.0)*np.arcsin(2*r2[i]/D))
print(theta2)
# Out:
# [0.09477344430078853, 0.07390645594345928, 0.06367846314017216, 0.0575947320190192, 0.05154553625133398, 0.0455268082248344, 0.0455268082248344, 0.0455268082248344, 0.04352665835615699, 0.039534652064273805, 0.035552786396441514, 0.035552786396441514]
# [0.14831143895426674, 0.12750335995787782, 0.10330893569146261, 0.0968960076923473, 0.08844780224565886, 0.08426359739405886, 0.07596683497381641, 0.07390645594345928, 0.06775556859330073, 0.06571477932776579, 0.06164645651220278, 0.05355835246025275]

# %%
x = []
y1 = []
y2 = []
for i in range(len(r1)):
  x.append((1.0/lamb[i]))
  y1.append(D/r1[i])
  y2.append(D/r2[i])

# print(x)
# print(y1)
# print(y2)

# print(x)
# print(y1)
# print(y2)

slope1, intercept1, r, p, std_err1 = stats.linregress(x, y1)
print(slope1, intercept1)

def myfunc(x):
  return slope1*x + intercept1

mymodel1 = list(map(myfunc, x))

slope2, intercept2, r, p, std_err2 = stats.linregress(x, y2)
print(slope2, intercept2)

def myfunc(x):
  return slope2*x + intercept2

mymodel2 = list(map(myfunc, x))
# Out:
# 243.23649488645202 -3.0637913001753176
# 153.07029693282362 -2.1079856694459664

# %%
fig1 = plt.figure(figsize=(8,6))
axes = fig1.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x, y1, "o", color="#1f77b4", label='Dados obtidos para o anel interno - r1')
axes.plot(x, y2, "o", color="#ff7f0e", label='Dados obtidos para o anel externo - r2')
axes.plot(x, mymodel1, "-", color="#1f77b4", label='Ajuste linear do anel interno')
axes.plot(x, mymodel2, "-", color="#ff7f0e", label='Ajuste linear do anel externo')
    
axes.set_xlabel('$1/λ$ (pm)')
axes.set_ylabel("$D/r$")

# axes.set_title(f'Ajuste linear dos dados obtidos para cada anel')
    
plt.grid(linestyle='-', linewidth=0.5)
axes.legend(loc='upper left')
    
plt.savefig(f'ajusteLinear.png', dpi=400)

# %%
d1 = []
d2 = []
for i in range(len(r1)):
  d1.append((2*65*(lamb[i]))/r1[i])
  d2.append((2*65*(lamb[i]))/r2[i])

print(np.mean(d1))
print(np.mean(d2))
# Out:
# 189.701723987718
# 116.0410493915719
